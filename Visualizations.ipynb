# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

sns.set_context('notebook')

x = ['No Incapacitating Injury Reported','Incapacitating or Fatal Injury']
y = [636726,11653]

fig,ax = plt.subplots(figsize = (7,7))

ax = sns.barplot(x = x, y = y)
ax.set_ylabel('Number of Accidents')

ax.set_title('Distribution of Injuries During Car Crashes');

# %%
import pandas as pd
data = pd.DataFrame({'Model' : ['Baseline','Decision Tree','Random Forest','Logistic Regression','Naive Bayes','Adaptive Boosting','XGBoost'], 'Recall Score' : ['0%','99.7%','99.9%','99.7%','96.6%','99.7%','99.9%'], 'False Positive Rate' : ['0%','20.9%','21.5%','21.4%','20.3%','20.8%','21.5%']})

data.set_index('Model')
# Out:
#                     Recall Score False Positive Rate
# Model
# Baseline                      0%                  0%
# Decision Tree              99.7%               20.9%
# Random Forest              99.9%               21.5%
# Logistic Regression        99.7%               21.4%
# Naive Bayes                96.6%               20.3%
# Adaptive Boosting          99.7%               20.8%
# XGBoost                    99.9%               21.5%

# %%
data2 = pd.DataFrame({'Model' : ['Decision Tree','Random Forest','Logistic Regression','Naive Bayes','Adaptive Boosting','XGBoost'], 'Recall Score' : [99.7,99.9,99.7,96.6,99.7,99.9], 'False Positive Rate' : [20.9,21.5,21.4,20.3,20.8,21.5]})

data2.set_index('Model')

fig, ax = plt.subplots(figsize = (15,7))

ax = sns.scatterplot(x = 'Recall Score', y = 'False Positive Rate', data = data2)
